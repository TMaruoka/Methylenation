# %%
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
datacsv = pd.read_csv('29dataset_dropped_opt.csv')
df = pd.DataFrame(data = datacsv)
df
# Out:
#    Unnamed: 0    E(RB3LYP)  Dipole Moment  Polarizability (a)  \
# 0          M1  -384.890280       2.976386           82.320667
# 1          M2  -384.891819       3.393730           82.941333
# 2          M3  -384.892348       3.780420           84.218000
# 3          M4  -460.095229       4.813919           87.394333
# 4          M5  -460.097202       2.178176           87.727333
# 5          M6  -460.098685       4.988572           90.681000
# 6          M7 -2916.675203       3.248754           88.329333
# 7          M8 -2916.676864       1.869718           89.644000
# 8          M9 -2916.677538       2.065982           91.846667
# 9         M10  -424.203430       2.994698           94.245667
# 10        M11  -479.545271       6.320322          111.650667
# 11        M12  -349.196145       2.728833           72.717333
# 12        M13  -682.609409       1.508276           82.503000
# 13        M14  -573.450618       3.735830          102.529333
# ...

# %%
A1 = df.iloc[0,0:].values
A2= df.iloc[1,0:].values
A3 = df.iloc[2,0:].values
A4 = df.iloc[3,0:].values
A5 = df.iloc[4,0:].values
A6 = df.iloc[5,0:].values
A7 = df.iloc[6,0:].values
A8 = df.iloc[7,0:].values
A9 = df.iloc[8,0:].values
A10 = df.iloc[9,0:].values
A11 = df.iloc[10,0:].values
A12 = df.iloc[11,0:].values
A13 = df.iloc[12,0:].values
A14 = df.iloc[13,0:].values
A15 = df.iloc[14,0:].values
A16 = df.iloc[15,0:].values
A17 = df.iloc[16,0:].values
A18 = df.iloc[17,0:].values
A19 = df.iloc[18,0:].values
A20 = df.iloc[19,0:].values
A21 = df.iloc[20,0:].values
A22 = df.iloc[21,0:].values
A23 = df.iloc[22,0:].values
A24 = df.iloc[23,0:].values
A25 = df.iloc[24,0:].values
A26 = df.iloc[25,0:].values
A27 = df.iloc[26,0:].values
A28 = df.iloc[27,0:].values
A29 = df.iloc[28,0:].values

# %%
#(M7,M18,rest except M8, M9, M26)

# %%
import itertools
sum = 0
frame = [A1,A2,A3,A4,A5,A6,A10,A11,A12,A13,A14,A15,A16,A17,A19,A20,A21,A22,A23,A24,A25,A27,A28,A29]
for pair in itertools.combinations(frame, 1):
#pairですべての組み合わせを求める(pairがテストデータ)
    dfpair = pd.DataFrame(data = pair)
    df1 = pd.read_csv('29dataset_dropped_opt.csv', index_col=0)
    df2 = pd.DataFrame(data = df1)
#datasetからpairの分を引き抜き(残ったdf13がトレーニングデータ)
#dfpairは0がMnumber,df2は0から入力値
    df11 = df2.drop(dfpair.iloc[0,0])
    df12 = df11.drop('M7')
    df15 = df12.drop('M18')
    
    X_train = df15.iloc[:26,:19]
    dfpair_a = dfpair.iloc[0,0:].values

    test = pd.DataFrame(data=(A7,A18,dfpair_a))
    y_train = df15.iloc[:26,19]
    X_test = test.iloc[:3,1:20]
    y_test = test.iloc[:3,20]
    
    from sklearn.linear_model import Lasso
    from sklearn.preprocessing import StandardScaler
    standard = StandardScaler()
    standard.fit(X_train)
    X_train_st_lasso = standard.transform(X_train)
    X_test_st_lasso = standard.transform(X_test)
    
    lasso = Lasso(alpha=0.01,random_state=0)
    lasso_train = lasso.fit(X_train_st_lasso, y_train)
    
    from sklearn.metrics import r2_score

    y_pred_lasso_train = lasso_train.predict(X_train_st_lasso)
    r2_score_lasso_train = r2_score(y_train, y_pred_lasso_train)

    y_pred_lasso_test = lasso_train.predict(X_test_st_lasso)
    r2_score_lasso_test = r2_score(y_test, y_pred_lasso_test)

    rmse_lasso = (np.sqrt(mean_squared_error(y_test, y_pred_lasso_test)))
    
    print(rmse_lasso)
    print(dfpair.iloc[0,0])
# Out:
# 0.09460974345864345
# M1
# 5.388590783145374
# M2
# 0.09110030238621368
# M3
# 0.15866972579576355
# M4
# 0.09593543582943963
# M5
# 0.09909900649490574
# M6
# 0.16496531372626913
# M10
# 0.12541495871085112
# M11
# 0.09157974895984694
# M12
# 0.09148134933389393
# M13
# 0.17071545410582503
# M14
# 0.11075769810669411
# M15
# 0.09666841160308849
# M16
# 0.12863733369226774
# M17
# 0.09387066955331115
# M19
# 0.16648087399132433
# M20
# 0.17809359929292928
# M21
# 0.1187115513258947
# M22
# 0.1212523133936651
# M23
# 0.12135385410641465
# M24
# 0.11019265677871518
# M25
# 0.17667056225335817
# M27
# 0.17912018088797696
# M28
# 0.2056293605826858
# M29

# %%
#(M8,M18,rest except M7, M9, M26)

# %%
import itertools
sum = 0

frame = [A1,A2,A3,A4,A5,A6,A10,A11,A12,A13,A14,A15,A16,A17,A19,A20,A21,A22,A23,A24,A25,A27,A28,A29]
for pair in itertools.combinations(frame, 1):
#pairですべての組み合わせを求める(pairがテストデータ)
    dfpair = pd.DataFrame(data = pair)
    df1 = pd.read_csv('29dataset_dropped_opt.csv', index_col=0)
    df2 = pd.DataFrame(data = df1)
#datasetからpairの分を引き抜き(残ったdf13がトレーニングデータ)
#dfpairは0がMnumber,df2は0から入力値
    df11 = df2.drop(dfpair.iloc[0,0])
    df12 = df11.drop('M8')
    df15 = df12.drop('M18')
    
    
    X_train = df15.iloc[:26,:19]
    dfpair_a = dfpair.iloc[0,0:].values

    test = pd.DataFrame(data=(A8,A18,dfpair_a))
    
    y_train = df15.iloc[:26,19]
    X_test = test.iloc[:3,1:20]
    y_test = test.iloc[:3,20]
    
    from sklearn.linear_model import Lasso
    from sklearn.preprocessing import StandardScaler
    standard = StandardScaler()
    standard.fit(X_train)
    X_train_st_lasso = standard.transform(X_train)
    X_test_st_lasso = standard.transform(X_test)
    
    lasso = Lasso(alpha=0.01,random_state=0)
    lasso_train = lasso.fit(X_train_st_lasso, y_train)
    
    from sklearn.metrics import r2_score

    y_pred_lasso_train = lasso_train.predict(X_train_st_lasso)
    r2_score_lasso_train = r2_score(y_train, y_pred_lasso_train)

    y_pred_lasso_test = lasso_train.predict(X_test_st_lasso)
    r2_score_lasso_test = r2_score(y_test, y_pred_lasso_test)

    rmse_lasso = (np.sqrt(mean_squared_error(y_test, y_pred_lasso_test)))
    
    print(rmse_lasso)
    print(dfpair.iloc[0,0])
# Out:
# 0.04898448488006053
# M1
# 5.347423341348573
# M2
# 0.05159999596717183
# M3
# 0.16045304090472517
# M4
# 0.0515120014084867
# M5
# 0.05925835791217125
# M6
# 0.15792111545527768
# M10
# 0.1626985735920443
# M11
# 0.05343545355025703
# M12
# 0.052016973719465724
# M13
# 0.1932988866230361
# M14
# 0.061462829656891024
# M15
# 0.0484174580349178
# M16
# 0.15824301159607593
# M17
# 0.050225704539309204
# M19
# 0.1736349027580823
# M20
# 0.14839659172329062
# M21
# 0.047557738774788944
# M22
# 0.07903445432016333
# M23
# 0.08185452236485863
# M24
# 0.10555885974310637
# M25
# 0.17928202764030246
# M27
# 0.17911137458620022
# M28
# 0.20967142743618372
# M29

# %%
#(M9,M18,rest except M7, M8, M26)

# %%
import itertools
sum = 0

frame = [A1,A2,A3,A4,A5,A6,A10,A11,A12,A13,A14,A15,A16,A17,A19,A20,A21,A22,A23,A24,A25,A27,A28,A29]
for pair in itertools.combinations(frame, 1):
#pairですべての組み合わせを求める(pairがテストデータ)
    dfpair = pd.DataFrame(data = pair)
    df1 = pd.read_csv('29dataset_dropped_opt.csv', index_col=0)
    df2 = pd.DataFrame(data = df1)
#datasetからpairの分を引き抜き(残ったdf13がトレーニングデータ)
#dfpairは0がMnumber,df2は0から入力値
    df11 = df2.drop(dfpair.iloc[0,0])
    df12 = df11.drop('M9')
    df15 = df12.drop('M18')
    
    X_train = df15.iloc[:26,:19]
    dfpair_a = dfpair.iloc[0,0:].values

    test = pd.DataFrame(data=(A9,A18,dfpair_a))
    y_train = df15.iloc[:26,19]
    X_test = test.iloc[:3,1:20]
    y_test = test.iloc[:3,20]
    
    from sklearn.linear_model import Lasso
    from sklearn.preprocessing import StandardScaler
    standard = StandardScaler()
    standard.fit(X_train)
    X_train_st_lasso = standard.transform(X_train)
    X_test_st_lasso = standard.transform(X_test)
    
    lasso = Lasso(alpha=0.01,random_state=0)
    lasso_train = lasso.fit(X_train_st_lasso, y_train)
    
    from sklearn.metrics import r2_score

    y_pred_lasso_train = lasso_train.predict(X_train_st_lasso)
    r2_score_lasso_train = r2_score(y_train, y_pred_lasso_train)

    y_pred_lasso_test = lasso_train.predict(X_test_st_lasso)
    r2_score_lasso_test = r2_score(y_test, y_pred_lasso_test)

    rmse_lasso = (np.sqrt(mean_squared_error(y_test, y_pred_lasso_test)))
    
    print(rmse_lasso)
# Out:
# 0.07790596511705099
# 5.052910171718428
# 0.08122875622410873
# 0.1633861008088732
# 0.0776853264081166
# 0.09073507980402341
# 0.1654645756688625
# 0.16109500758599912
# 0.07949864550229033
# 0.08462099243425039
# 0.22333271227861262
# 0.08228692616180133
# 0.07795030010804405
# 0.16016388036273507
# 0.0790427407338234
# 0.1756743039528896
# 0.16224017104919689
# 0.07619056611508698
# 0.10308174883413608
# 0.1018335442841355
# 0.1161100769316536
# 0.20088926597853674
# 0.19989060577048748
# 0.22087779108750352

# %%
#(M7,M26,rest except M9, M8, M18)

# %%
import itertools
sum = 0

frame = [A1,A2,A3,A4,A5,A6,A10,A11,A12,A13,A14,A15,A16,A17,A19,A20,A21,A22,A23,A24,A25,A27,A28,A29]
for pair in itertools.combinations(frame, 1):
#pairですべての組み合わせを求める(pairがテストデータ)
    dfpair = pd.DataFrame(data = pair)
    df1 = pd.read_csv('29dataset_dropped_opt.csv', index_col=0)
    df2 = pd.DataFrame(data = df1)
#datasetからpairの分を引き抜き(残ったdf13がトレーニングデータ)
#dfpairは0がMnumber,df2は0から入力値
    df11 = df2.drop(dfpair.iloc[0,0])
    df12 = df11.drop('M7')
    df15 = df12.drop('M26')
    
    X_train = df15.iloc[:26,:19]
    dfpair_a = dfpair.iloc[0,0:].values

    test = pd.DataFrame(data=(A7,A26,dfpair_a))
    y_train = df15.iloc[:26,19]
    X_test = test.iloc[:3,1:20]
    y_test = test.iloc[:3,20]
    
    from sklearn.linear_model import Lasso
    from sklearn.preprocessing import StandardScaler
    standard = StandardScaler()
    standard.fit(X_train)
    X_train_st_lasso = standard.transform(X_train)
    X_test_st_lasso = standard.transform(X_test)
    
    lasso = Lasso(alpha=0.01,random_state=0)
    lasso_train = lasso.fit(X_train_st_lasso, y_train)
    
    from sklearn.metrics import r2_score

    y_pred_lasso_train = lasso_train.predict(X_train_st_lasso)
    r2_score_lasso_train = r2_score(y_train, y_pred_lasso_train)

    y_pred_lasso_test = lasso_train.predict(X_test_st_lasso)
    r2_score_lasso_test = r2_score(y_test, y_pred_lasso_test)

    rmse_lasso = (np.sqrt(mean_squared_error(y_test, y_pred_lasso_test)))
    
    print(rmse_lasso)
# Out:
# 0.14053441110895454
# 3.4872107196412596
# 0.14053138452968628
# 0.2033443489646157
# 0.14103037588378664
# 0.14644100543033137
# 0.20970503572956428
# 0.14897766318774852
# 0.1415865399673393
# 0.13989787371803078
# 0.22101825015809315
# 0.15932676069928312
# 0.14268131827735056
# 0.15474602705454946
# 0.13969437313041827
# 0.18428734203384567
# 0.18966483402470682
# 0.17570930115034508
# 0.1408623990583229
# 0.17352641536099628
# 0.15283700657161184
# 0.18671165218594102
# 0.19813759561485797
# 0.23542120310421805

# %%
#(M8,M26,rest except M9, M7, M18)

# %%
import itertools
sum = 0

frame = [A1,A2,A3,A4,A5,A6,A10,A11,A12,A13,A14,A15,A16,A17,A19,A20,A21,A22,A23,A24,A25,A27,A28,A29]
for pair in itertools.combinations(frame, 1):
#pairですべての組み合わせを求める(pairがテストデータ)
    dfpair = pd.DataFrame(data = pair)
    df1 = pd.read_csv('29dataset_dropped_opt.csv', index_col=0)
    df2 = pd.DataFrame(data = df1)
#datasetからpairの分を引き抜き(残ったdf13がトレーニングデータ)
#dfpairは0がMnumber,df2は0から入力値
    df11 = df2.drop(dfpair.iloc[0,0])
    df12 = df11.drop('M8')
    df15 = df12.drop('M26')
    
    X_train = df15.iloc[:26,:19]
    dfpair_a = dfpair.iloc[0,0:].values

    test = pd.DataFrame(data=(A8,A26,dfpair_a))
    y_train = df15.iloc[:26,19]
    X_test = test.iloc[:3,1:20]
    y_test = test.iloc[:3,20]
    
    from sklearn.linear_model import Lasso
    from sklearn.preprocessing import StandardScaler
    standard = StandardScaler()
    standard.fit(X_train)
    X_train_st_lasso = standard.transform(X_train)
    X_test_st_lasso = standard.transform(X_test)
    
    lasso = Lasso(alpha=0.01,random_state=0)
    lasso_train = lasso.fit(X_train_st_lasso, y_train)
    
    from sklearn.metrics import r2_score

    y_pred_lasso_train = lasso_train.predict(X_train_st_lasso)
    r2_score_lasso_train = r2_score(y_train, y_pred_lasso_train)

    y_pred_lasso_test = lasso_train.predict(X_test_st_lasso)
    r2_score_lasso_test = r2_score(y_test, y_pred_lasso_test)

    rmse_lasso = (np.sqrt(mean_squared_error(y_test, y_pred_lasso_test)))
    
    print(rmse_lasso)
# Out:
# 0.1407686217599056
# 3.87319897542727
# 0.14051662507105628
# 0.20767151028552341
# 0.14459867620151326
# 0.14075044767076453
# 0.22735698230082543
# 0.16814702994885614
# 0.14471639114519744
# 0.14011916203149544
# 0.24828755102086444
# 0.1714815994513379
# 0.13891651141437614
# 0.180820338446825
# 0.14034955208813538
# 0.18352582651343743
# 0.1913969134326397
# 0.16930667400915803
# 0.13852538318375265
# 0.18087157108878232
# 0.15695142589275188
# 0.1813546489866494
# 0.2177343739211052
# 0.23854305560714273

# %%
#(M9,M26,rest except M8, M7, M18)

# %%
import itertools
sum = 0

frame = [A1,A2,A3,A4,A5,A6,A10,A11,A12,A13,A14,A15,A16,A17,A19,A20,A21,A22,A23,A24,A25,A27,A28,A29]
for pair in itertools.combinations(frame, 1):
#pairですべての組み合わせを求める(pairがテストデータ)
    dfpair = pd.DataFrame(data = pair)
    df1 = pd.read_csv('29dataset_dropped_opt.csv', index_col=0)
    df2 = pd.DataFrame(data = df1)
#datasetからpairの分を引き抜き(残ったdf13がトレーニングデータ)
#dfpairは0がMnumber,df2は0から入力値
    df11 = df2.drop(dfpair.iloc[0,0])
    df12 = df11.drop('M9')
    df15 = df12.drop('M26')
    
    X_train = df15.iloc[:26,:19]
    dfpair_a = dfpair.iloc[0,0:].values

    test = pd.DataFrame(data=(A9,A26,dfpair_a))
    y_train = df15.iloc[:26,19]
    X_test = test.iloc[:3,1:20]
    y_test = test.iloc[:3,20]
    
    from sklearn.linear_model import Lasso
    from sklearn.preprocessing import StandardScaler
    standard = StandardScaler()
    standard.fit(X_train)
    X_train_st_lasso = standard.transform(X_train)
    X_test_st_lasso = standard.transform(X_test)
    
    lasso = Lasso(alpha=0.01,random_state=0)
    lasso_train = lasso.fit(X_train_st_lasso, y_train)
    
    from sklearn.metrics import r2_score

    y_pred_lasso_train = lasso_train.predict(X_train_st_lasso)
    r2_score_lasso_train = r2_score(y_train, y_pred_lasso_train)

    y_pred_lasso_test = lasso_train.predict(X_test_st_lasso)
    r2_score_lasso_test = r2_score(y_test, y_pred_lasso_test)

    rmse_lasso = (np.sqrt(mean_squared_error(y_test, y_pred_lasso_test)))
    
    print(rmse_lasso)
# Out:
# 0.16237345159264316
# 3.6540107220880347
# 0.16305383990719446
# 0.20839118759951
# 0.165012200907596
# 0.16566020664247658
# 0.23297018011398005
# 0.16764170334617087
# 0.1636414839482477
# 0.16281544637421452
# 0.27143833283513996
# 0.18387735585225587
# 0.16192771047723087
# 0.19267679137100466
# 0.1624734349163307
# 0.19088595031031735
# 0.20517631088173618
# 0.2135882624432084
# 0.16194586821219087
# 0.17764492354317243
# 0.16803308479245102
# 0.20103494108687708
# 0.24008513820359273
# 0.24963788583212682
