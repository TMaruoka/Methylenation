# %%
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

datacsv = pd.read_csv('29dataset_dropped_opt.csv', index_col=0)
df = pd.DataFrame(data = datacsv)
df
# Out:
#        E(RB3LYP)  Dipole Moment  Polarizability (a)  \
# M1   -384.890280       2.976386           82.320667
# M2   -384.891819       3.393730           82.941333
# M3   -384.892348       3.780420           84.218000
# M4   -460.095229       4.813919           87.394333
# M5   -460.097202       2.178176           87.727333
# M6   -460.098685       4.988572           90.681000
# M7  -2916.675203       3.248754           88.329333
# M8  -2916.676864       1.869718           89.644000
# M9  -2916.677538       2.065982           91.846667
# M10  -424.203430       2.994698           94.245667
# M11  -479.545271       6.320322          111.650667
# M12  -349.196145       2.728833           72.717333
# M13  -682.609409       1.508276           82.503000
# M14  -573.450618       3.735830          102.529333
# M15  -361.609323       3.665587           65.770333
# M16  -682.608975       1.666873           83.178667
# M17  -546.968781       2.493996          132.582667
# M18 -1264.748798       4.137538           93.296667
# M19  -499.414704       4.826996           99.196000
# M20  -463.555153       3.387544          112.221333
# M21  -574.610694       4.857860          105.110000
# M22  -615.926162       2.767991          139.447667
# M23  -691.147396       4.772669          147.896000
# M24  -429.021298       2.415239           96.330667
# M25  -424.195052       2.438840           90.539333
# M26  -947.439748       4.850279          161.397333
# M27  -550.072256       2.203458           86.855333
# M28  -345.786542       3.008029           55.036333
# M29  -515.587779       2.721616           77.029333
#
#      Zero-point Energy Correction  C=O stretch\nFrequency  \
# M1                       0.138206                 1792.56
# M2                       0.137724                 1799.19
# M3                       0.137661                 1797.59
# M4                       0.143198                 1782.58
# M5                       0.143040                 1796.18
# M6                       0.143103                 1792.93
# M7                       0.100233                 1791.24
# M8                       0.100118                 1804.15
# M9                       0.100110                 1800.83
# M10                      0.166295                 1778.72
# M11                      0.183685                 1784.17
# M12                      0.180130                 1827.81
# M13                      0.114962                 1804.66
# M14                      0.151851                 1798.04
# M15                      0.098317                 1807.67
# M16                      0.114930                 1804.54
# M17                      0.342308                 1832.83
# M18                      0.090566                 1802.42
# M19                      0.171576                 1781.88
# M20                      0.192211                 1773.06
# M21                      0.175797                 1785.15
# M22                      0.219462                 1824.49
# M23                      0.224333                 1781.26
# M24                      0.255527                 1829.08
# M25                      0.166584                 1831.46
# M26                      0.301905                 1781.40
# M27                      0.112756                 1807.00
# M28                      0.122787                 1828.73
# M29                      0.173177                 1832.71
#
#      C=O stretch\nRaman Activity  C=O stretch\nDepolar-P  \
# M1                       67.2699                  0.3176
# M2                       82.1492                  0.3278
# M3                      103.3745                  0.3431
# M4                       82.3785                  0.2987
# M5                       87.0887                  0.3267
# M6                      139.4349                  0.3464
# M7                       61.3724                  0.2859
# M8                       84.9797                  0.3394
# M9                      146.4000                  0.3339
# M10                      64.2892                  0.2735
# M11                     214.4432                  0.3475
# M12                      12.6543                  0.4832
# M13                      82.2709                  0.3432
# M14                     127.3239                  0.3420
# M15                      69.2005                  0.3374
# M16                      93.6066                  0.3326
# M17                       7.2773                  0.5603
# M18                      54.6829                  0.2500
# M19                      81.0742                  0.2964
# M20                      86.7281                  0.2792
# M21                      73.4562                  0.2624
# M22                      18.7232                  0.2546
# M23                      77.1059                  0.2916
# M24                       6.3763                  0.5230
# M25                       8.5767                  0.6838
# M26                      74.3470                  0.3035
# M27                      80.2775                  0.3525
# M28                       5.4976                  0.3879
# M29                       7.1122                  0.5170
#
#      C2-H stretch\nFrequency  C2-H stretch\nDepolar-P  O NBO Charge  ...  \
# M1                   2895.10                   0.2969        -0.536  ...
# M2                   2905.37                   0.3060        -0.531  ...
# M3                   2903.04                   0.3077        -0.533  ...
# M4                   2995.61                   0.2999        -0.541  ...
# M5                   2913.73                   0.3037        -0.533  ...
# M6                   2896.49                   0.3137        -0.540  ...
# M7                   3000.48                   0.2480        -0.525  ...
# M8                   2918.78                   0.3033        -0.521  ...
# M9                   2913.59                   0.2997        -0.525  ...
# M10                  2962.69                   0.3055        -0.540  ...
# M11                  2886.74                   0.3263        -0.552  ...
# M12                  2877.41                   0.3475        -0.529  ...
# M13                  2920.27                   0.2973        -0.521  ...
# M14                  2908.90                   0.3074        -0.531  ...
# M15                  2966.96                   0.3031        -0.524  ...
# M16                  2918.95                   0.2994        -0.518  ...
# M17                  2890.51                   0.3585        -0.530  ...
# M18                  3015.69                   0.2694        -0.501  ...
# M19                  2995.01                   0.2966        -0.542  ...
# M20                  2927.21                   0.3051        -0.536  ...
# M21                  2986.62                   0.3091        -0.528  ...
# M22                  2921.26                   0.3830        -0.521  ...
# M23                  2999.53                   0.2990        -0.543  ...
# M24                  2888.05                   0.3544        -0.535  ...
# M25                  2894.49                   0.3433        -0.529  ...
# M26                  2986.21                   0.2890        -0.542  ...
# M27                  2931.28                   0.3125        -0.516  ...
# M28                  2918.46                   0.3537        -0.537  ...
# M29                  2913.08                   0.3474        -0.528  ...
#
#          L    B1    B5  LUMO(chk)  HOMO(chk)  X=O(ONBO)  X=O(CNBO)  \
# M1    6.75  1.76  4.33    0.01238   -0.24837      0.000      0.000
# M2    6.75  1.76  4.40    0.01381   -0.24819      0.000      0.000
# M3    7.70  1.81  3.16    0.01495   -0.25054      0.000      0.000
# M4    6.76  1.75  5.37    0.02047   -0.24760      0.000      0.000
# M5    6.75  1.75  5.35    0.01238   -0.25296      0.000      0.000
# M6    8.85  1.78  3.18    0.01690   -0.25130      0.000      0.000
# M7    6.78  1.78  4.86   -0.00043   -0.26416      0.000      0.000
# M8    6.86  1.77  4.83   -0.00168   -0.26249      0.000      0.000
# M9    8.51  1.95  3.16   -0.00253   -0.26684      0.000      0.000
# M10   6.81  1.88  5.60   -0.06031   -0.24371      0.000      0.000
# M11   8.89  1.89  3.17    0.02576   -0.23705      0.000      0.000
# M12   6.68  1.93  3.52    0.01421   -0.26174      0.000      0.000
# M13   7.25  1.79  4.92    0.00014   -0.27004      0.000      0.000
# M14  10.00  1.78  3.47   -0.00406   -0.25795     -0.571      0.833
# M15   6.69  1.70  3.24   -0.00411   -0.26705      0.000      0.000
# M16   8.05  1.90  3.16   -0.00074   -0.27076      0.000      0.000
# M17  14.26  1.87  8.83    0.01097   -0.26308      0.000      0.000
# M18   6.81  1.80  4.57   -0.01430   -0.26936      0.000      0.000
# M19   6.76  1.75  6.69    0.02128   -0.24650      0.000      0.000
# M20   7.70  1.88  4.39    0.02192   -0.23665      0.000      0.000
# M21   6.77  1.89  5.36    0.02379   -0.23255      0.000      0.000
# M22   5.86  2.27  6.20    0.01122   -0.24396      0.000      0.000
# M23   6.76  1.99  8.52    0.02269   -0.24588      0.000      0.000
# M24   7.52  1.93  5.64    0.01069   -0.26463      0.000      0.000
# M25   8.95  1.91  3.54    0.00718   -0.23816      0.000      0.000
# M26   6.76  2.09  7.99    0.02177   -0.24605      0.000      0.000
# M27   7.29  1.70  4.85   -0.14310   -0.28096     -0.377      0.054
# M28   4.58  1.85  5.66    0.00563   -0.25566     -0.541      0.598
# M29   6.72  1.90  4.63   -0.12886   -0.27502     -0.380      0.091
#
#      C Length(X=O,CHO)  A_para  B_para
# M1             0.00000    0.74    0.31
# M2             0.00000    0.78    0.39
# M3             0.00000    0.79    0.36
# M4             0.00000    0.98    0.49
# M5             0.00000    0.73    0.42
# M6             0.00000    0.84    0.29
# M7             0.00000    0.73    0.53
# M8             0.00000    0.76    0.62
# M9             0.00000    0.89    0.56
# M10            0.00000    0.98    0.28
# M11            0.00000    0.70    0.08
# M12            0.00000    0.68    0.24
# M13            0.00000    0.81    0.63
# M14            6.55162    0.76    0.41
# M15            0.00000    0.71    0.17
# M16            0.00000    0.79    0.55
# M17            0.00000    0.79    0.39
# M18            0.00000    0.90    0.63
# M19            0.00000    0.75    0.42
# M20            0.00000    0.56    0.16
# M21            0.00000    0.53    0.16
# M22            0.00000    0.68    0.39
# M23            0.00000    0.72    0.93
# M24            0.00000    0.82    0.17
# M25            0.00000    0.77    0.56
# M26            0.00000    0.97    0.35
# M27            3.76137    0.96    0.63
# M28            3.86981    0.47    0.69
# M29            3.91265    0.58    0.48
#
# [29 rows x 21 columns]

# %%
df2 = df.drop('M8')
df3 = df2.drop('M18')
df4 = df3.drop('M1')

X_train = df4.iloc[:26,:19].values  # 説明変数
y_train = df4.iloc[:26,20].values   # 目的変数

A8 =df.iloc[7,0:]
A18 =df.iloc[17,0:]
A1 =df.iloc[0,0:]

testframe = pd.DataFrame(data = (A8,A18,A1))

X_test = testframe.iloc[0:3,:19]
y_test = testframe.iloc[0:3,20]

from sklearn.linear_model import Lasso
from sklearn.preprocessing import StandardScaler

standard = StandardScaler()
standard.fit(X_train)
X_train_st_lasso = standard.transform(X_train)
X_test_st_lasso = standard.transform(X_test)

lasso = Lasso(alpha=0.01,random_state=0)
lasso_train = lasso.fit(X_train_st_lasso, y_train)

from sklearn.metrics import r2_score

y_pred_lasso_train = lasso_train.predict(X_train_st_lasso)
r2_score_lasso_train = r2_score(y_train, y_pred_lasso_train)

print(y_pred_lasso_train)

y_pred_lasso_test = lasso_train.predict(X_test_st_lasso)
r2_score_lasso_test = r2_score(y_test, y_pred_lasso_test)

rmse_lasso = (np.sqrt(mean_squared_error(y_test, y_pred_lasso_test)))
# print('CV: ', cv_lasso.mean())
print('R2_score (train): ', r2_score_lasso_train)
print('R2_score (test): ', r2_score_lasso_test)
print("RMSE: ", rmse_lasso)
print(lasso_train.coef_, lasso_train.intercept_)

plt.scatter(y_train, y_pred_lasso_train, color='black', label="トレーニングデータ")
plt.scatter(y_test, y_pred_lasso_test, color='red', label="テストデータ")
plt.plot([0,1], [0,1], color='black')
plt.grid()
plt.xlabel('実験値', fontname="MS Gothic", fontsize=15)
plt.ylabel('予測値', fontname="MS Gothic", fontsize=15)
plt.legend(loc='upper left', prop = {"family" : "MS Gothic"})
# Out:
# [0.36923994 0.27197635 0.41458897 0.47186887 0.25602449 0.56663763
#  0.48995866 0.39765769 0.15510009 0.26054022 0.55892493 0.40429726
#  0.36590051 0.40547097 0.40830788 0.46970307 0.23584704 0.32990233
#  0.43970731 0.62073088 0.29746225 0.44880171 0.36827949 0.62232118
#  0.61370968 0.48704059]
# R2_score (train):  0.7074767132810533
# R2_score (test):  0.8678429712296964
# RMSE:  0.054002454588021886
# [-0.00417422 -0.01558055  0.06363323 -0.19939327  0.          0.
#   0.06188994 -0.         -0.         -0.          0.          0.
#   0.01676243  0.1510841   0.         -0.01533946 -0.02441014  0.00379505
#   0.        ] 0.4126923076923077

# %%
#追加基質予測

# %%
Ad_csv = pd.read_csv('Additional_prediction.csv', index_col=0)
Ad = pd.DataFrame(data = Ad_csv)
Ad
# Out:
#                                    E(RB3LYP)  Dipole Moment  \
# M31_benzaldehyde_flow            -345.582685       3.281821
# M32_2-Phenylpropionaldehyde_flow -424.207840       2.665890
#
#                                   Polarizability (a)  \
# M31_benzaldehyde_flow                      70.842000
# M32_2-Phenylpropionaldehyde_flow           90.686333
#
#                                   Zero-point Energy Correction  \
# M31_benzaldehyde_flow                                 0.110011
# M32_2-Phenylpropionaldehyde_flow                      0.166822
#
#                                   C=O stretch\nFrequency  \
# M31_benzaldehyde_flow                            1799.21
# M32_2-Phenylpropionaldehyde_flow                 1828.14
#
#                                   C=O stretch\nRaman Activity  \
# M31_benzaldehyde_flow                                 77.4428
# M32_2-Phenylpropionaldehyde_flow                      16.0672
#
#                                   C=O stretch\nDepolar-P  \
# M31_benzaldehyde_flow                             0.3405
# M32_2-Phenylpropionaldehyde_flow                  0.3699
#
#                                   C2-H stretch\nFrequency  \
# M31_benzaldehyde_flow                             2896.88
# M32_2-Phenylpropionaldehyde_flow                  2887.02
#
#                                   C2-H stretch\nDepolar-P  O NBO Charge  \
# M31_benzaldehyde_flow                              0.2989        -0.528
# M32_2-Phenylpropionaldehyde_flow                   0.3746        -0.525
#
#                                   C2-O length     L   B1    B5  LUMO(chk)  \
# M31_benzaldehyde_flow                 1.21628  6.28  1.7  3.11    0.01142
# M32_2-Phenylpropionaldehyde_flow      1.21000  7.03  1.7  6.24   -0.03106
#
#                                   HOMO(chk)  X=O(ONBO)  X=O(CNBO)  \
# M31_benzaldehyde_flow              -0.25468          0          0
# M32_2-Phenylpropionaldehyde_flow   -0.23936          0          0
#
#                                   C Length(X=O,CHO)
# M31_benzaldehyde_flow                             0
# M32_2-Phenylpropionaldehyde_flow                  0

# %%
X_add = Ad.iloc[:5,:19].values  # 説明変数
X_add_st_lasso = standard.transform(X_add)

y_pred_lasso_add = lasso_train.predict(X_add_st_lasso)
print(y_pred_lasso_add)
# Out:
# [0.3197282  0.47830584]
